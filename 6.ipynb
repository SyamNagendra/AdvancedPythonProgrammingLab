# %% [markdown]
# CREATE A DATAFRAME MANUALLY

# %%
import numpy as np
import pandas as pd
data=[1,2,3,4,5]   #from lists
a=pd.DataFrame(data)
print(a)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
data=[['alex',10],['bob',12],['kim',13]]   #from dictionaries
b=pd.DataFrame(data)
b
# Out:
#       0   1
# 0  alex  10
# 1   bob  12
# 2   kim  13

# %%
data={'Name':['tom','kim','bob'],'Age':[20,25,30]}
c=pd.DataFrame(data)
c
# Out:
#   Name  Age
# 0  tom   20
# 1  kim   25
# 2  bob   30

# %% [markdown]
# Pairwise Plots

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/drive/MyDrive/csv/Toyota.csv',index_col=0)
df.head()
# Out:
#    Price   Age     KM FuelType  HP  MetColor  Automatic    CC  Doors  Weight
# 0  13500  23.0  46986   Diesel  90       1.0          0  2000  three    1165
# 1  13750  23.0  72937   Diesel  90       1.0          0  2000      3    1165
# 2  13950  24.0  41711   Diesel  90       NaN          0  2000      3    1165
# 3  14950  26.0  48000   Diesel  90       0.0          0  2000      3    1165
# 4  13750  30.0  38500   Diesel  90       0.0          0  2000      3    1170

# %%
import seaborn as sns
sns.pairplot(df,kind="scatter",hue='FuelType')
